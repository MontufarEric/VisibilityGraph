# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import os 
import networkx as nx

# %%
congestivosDormidos = pd.read_csv('./CongestivosDormidos.csv')
congestivosDespiertos = pd.read_csv('./CongestivosDespiertos.csv')
sanosDormidos = pd.read_csv('./SanosDormidos.csv')
sanosDespiertos = pd.read_csv('./SanosDespiertos.csv')

# %%
sanosDespiertos.head()
# Out:
#    Unnamed: 0     name  average_clustering_coef  average_shortest_path_lenght  \
# 0           0  nsr29w_                 0.737019                      5.597345
# 1           0  nsr27w_                 0.726763                      7.468041
# 2           0  nsr25w_                 0.752833                      5.180417
# 3           0  nsr26w_                 0.746715                      5.152543
# 4           0  nsr23w_                 0.740534                      6.031555
#
#    centrality_betweeness  centrality_closeness  centrality_eigenvector  \
# 0               0.000138              0.182674                0.001257
# 1               0.000192              0.136971                0.000426
# 2               0.000124              0.197229                0.001568
# 3               0.000125              0.199077                0.001471
# 4               0.000163              0.168502                0.000710
#
#    average_degree  diameter  modularity_greedy
# ...

# %%
sanosDormidos.head()
# Out:
#    Unnamed: 0     name  average_clustering_coef  average_shortest_path_lenght  \
# 0           0  nsr35s_                 0.746599                      6.374218
# 1           0  nsr24s_                 0.751986                      5.575000
# 2           0  nsr25s_                 0.761573                      7.285816
# 3           0  nsr36s_                 0.742045                      5.790616
# 4           0  nsr31s_                 0.744676                      6.090900
#
#    centrality_betweeness  centrality_closeness  centrality_eigenvector  \
# 0               0.000159              0.159815                0.001435
# 1               0.000144              0.182894                0.001326
# 2               0.000211              0.139714                0.000423
# 3               0.000180              0.176414                0.001373
# 4               0.000209              0.166721                0.000000
#
#    average_degree  diameter  modularity_greedy
# ...

# %% [markdown]
# ## Average Clustering Coefficient

# %% [markdown]
# ### Despiertos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['average_clustering_coef'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['average_clustering_coef'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Average Clustering Coefficient',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDormidos['average_clustering_coef'], shade=True, color="r")
p1=sns.kdeplot(sanosDormidos['average_clustering_coef'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Average Clustering Coefficient',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Average Shortest Path Length

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['average_shortest_path_lenght'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['average_shortest_path_lenght'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Average Shortest Path Length',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDormidos['average_shortest_path_lenght'], shade=True, color="r")
p1=sns.kdeplot(sanosDormidos['average_shortest_path_lenght'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Average Shortest Path Length',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Centrality betweeness

# %% [markdown]
# ### Despiertos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['centrality_betweeness'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['centrality_betweeness'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('centality betweeness',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDormidos['centrality_betweeness'], shade=True, color="r")
p1=sns.kdeplot(sanosDormidos['centrality_betweeness'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('centality betweeness',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Centrality Closeness

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['centrality_closeness'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['centrality_closeness'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Centrality Closeness',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDormidos['centrality_closeness'], shade=True, color="r")
p1=sns.kdeplot(sanosDormidos['centrality_closeness'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Centrality Closeness',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Centrality Eigenvector

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['centrality_eigenvector'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['centrality_eigenvector'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Centrality Eigenvector',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDormidos['centrality_eigenvector'], shade=True, color="r")
p1=sns.kdeplot(sanosDormidos['centrality_eigenvector'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Centrality Eigenvector',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Average Degree

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['average_degree'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['average_degree'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Average Degree',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDormidos['average_degree'], shade=True, color="r")
p1=sns.kdeplot(sanosDormidos['average_degree'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Average Degree',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()

# %% [markdown]
# ## Diameter

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['diameter'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['diameter'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Diameter',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos

# %% [markdown]
# ## Modularity Greedy

# %% [markdown]
# ### Despiertos

# %%
# plot of 2 variables
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,2,2])
p1=sns.kdeplot(congestivosDespiertos['modularity_greedy'], shade=True, color="r")
p1=sns.kdeplot(sanosDespiertos['modularity_greedy'], shade=True, color="b")
plt.legend(['CHF','Healthy'],fontsize=12)
plt.xlabel('Modularity Greedy',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
#sns.plt.show()
# Out:
# /home/eric/anaconda3/envs/tesina/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Dormidos
